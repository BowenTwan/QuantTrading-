# %%
import tushare as ts
from tushare import stock
import pandas as pd
import datetime
import sys
import os

# set up token
pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')

# download all stock daily data 
# save data in csv file for each stock

# downloading data up to today
today = datetime.datetime.now().strftime('%Y%m%d')

# prepare file saving path
father_dir = os.path.dirname(os.path.abspath(sys.argv[0])) 
save_path = os.path.join(father_dir, 'AstockDailyData/')

# loading all the stock listed on both shanghai and shenzhen market
stock_list = pro.stock_basic(exchange='', list_status='', fields='ts_code,symbol,name,area,industry,list_date')
# save stock list
stock_list.to_csv(f'{save_path}StockList{today}.csv')
print(f'stock list downloaded')
# Out:
# stock list downloaded

# %%
stock_data = pro.daily(ts_code='000001.SZ', start_date='20190101', end_date=today)
#file_name = f'{save_path}{stock_code}.csv'
col = ['ts_code','trade_date','open','high','low','close','vol','amount']
stock_price_data = stock_data[col].copy()
stock_price_data.sort_values(by= 'trade_date', ascending = True)
# Out:
#        ts_code trade_date   open   high    low  close         vol       amount
# 499  000001.SZ   20190102   9.39   9.42   9.16   9.19   539386.32   498695.109
# 498  000001.SZ   20190103   9.18   9.33   9.15   9.28   415537.95   384457.707
# 497  000001.SZ   20190104   9.24   9.82   9.22   9.75  1481159.06  1422149.888
# 496  000001.SZ   20190107   9.84   9.85   9.63   9.74   865687.66   841166.430
# 495  000001.SZ   20190108   9.73   9.74   9.62   9.66   402388.11   389247.795
# ..         ...        ...    ...    ...    ...    ...         ...          ...
# 4    000001.SZ   20210114  20.68  20.89  19.95  20.17  1130155.62  2306404.546
# 3    000001.SZ   20210115  21.00  21.95  20.82  21.00  2480688.98  5311218.074
# 2    000001.SZ   20210118  21.20  22.78  21.20  22.70  2157301.78  4792909.447
# 1    000001.SZ   20210119  22.51  22.84  22.05  22.34  1242088.34  2790056.611
# 0    000001.SZ   20210120  22.15  22.97  22.12  22.47  1280793.16  2889249.850
#
# [500 rows x 8 columns]

# %%
# loading stock data 
print(f'starting to dowmload daily data up to {today}')
i = 0

col = ['ts_code','trade_date','open','high','low','close','vol','amount']

for stock_code in stock_list['ts_code']:
    try: 
        stock_data = pro.daily(ts_code=stock_code, start_date='20190101', end_date=today)
        file_name = f'{save_path}{stock_code}.csv'
        stock_price_data = stock_data[col].copy()
        stock_price_data.sort_values(by= 'trade_date', acending = True).to_csv(file_name, index=False)
        i = i + 1
        
    except:
         print(f'{stock_code} downlaoding data failed')
        
print(f'downloading complete, {i} stocks dowlanded')

# %%
# !pip install mysql-connector

# %%
import mysql.connector as mysql

db = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@')
cursor = db.cursor()
cursor.execute("DROP DATABASE IF EXISTS test; CREATE DATABASE test")

# %%
print(mysql.connect.__path__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-0c9a09fb02d0> in <module>
# ----> 1 print(mysql.connect.__path__)
#
# AttributeError: 'function' object has no attribute '__path__'

# %%
import pandas as pd
import tushare as ts
import datetime

today = datetime.datetime.now().strftime('%Y%m%d')
pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')
stock_list = pro.stock_basic(exchange='', list_status='',\
    fields='ts_code,symbol,name,area,industry,fullname,enname,market,exchange,curr_type,list_status,list_date,delist_date,is_hs')
stock_list.head()
# Out:
#      ts_code  symbol  name area industry         fullname  \
# 0  000001.SZ  000001  平安银行   深圳       银行       平安银行股份有限公司
# 1  000002.SZ  000002   万科A   深圳     全国地产       万科企业股份有限公司
# 2  000004.SZ  000004  国华网安   深圳      互联网   深圳国华网安科技股份有限公司
# 3  000005.SZ  000005  世纪星源   深圳     环境保护     深圳世纪星源股份有限公司
# 4  000006.SZ  000006  深振业A   深圳     区域地产  深圳市振业(集团)股份有限公司
#
#                                               enname market exchange  \
# 0                             Ping An Bank Co., Ltd.     主板     SZSE
# 1                               China Vanke Co.,Ltd.     主板     SZSE
# 2  Shenzhen GuoHua Network Security Technology Co...     主板     SZSE
# 3                      Shenzhen Fountain Corporation     主板     SZSE
# 4                    Shenzhen Zhenye(Group) Co.,Ltd.     主板     SZSE
#
#   curr_type list_status list_date delist_date is_hs
# 0       CNY           L  19910403        None     S
# 1       CNY           L  19910129        None     S
# ...

# %%
import mysql.connector as mysql
from mysql.connector import charsets
from mysql.connector.errors import Error
import pandas as pd
import tushare as ts
import datetime

try:
    conn = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@')
    if conn.is_connected():
        mycursor = conn.cursor(buffered=True)
        mycursor.execute('USE AStockMarket')
        print('Database AStockMarket is connected!')
        
        # get stock code from database
        # mycursor.execute('select ts_code from StockList')
        stock_list = ('000001.SZ','000002.SZ')
        sql = "INSERT INTO Daily VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
        

        # downloading each stock data from 20080101 to 2020121 from Tusahre
    for stock_code in stock_list:
        df = pro.daily(ts_code=stock_code, start_date='20080101', end_date='20200121')
        print(df)
# Out:
#   File "<ipython-input-1-32e213667a6d>", line 23
#     print(df)
#              ^
# SyntaxError: unexpected EOF while parsing

# %%
import tushare as ts
import mysql.connector as mysql
from mysql.connector import charsets
from mysql.connector.errors import Error
import pandas as pd
import tushare as ts
import datetime

stock_list = ('000001.SZ','000002.SZ')

conn = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@')
mycursor = conn.cursor(buffered=True)
mycursor.execute('USE AStockMarket')
print('Database AStockMarket is connected!')

sql = "INSERT INTO Daily VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"

for stock_code in stock_list:
    pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')
    df = pro.daily(ts_code=stock_code, start_date='20080101', end_date='20200121')
    print(f'downloading {stock_code} data from 20080101 to 2020121 from Tusahre')

    value = df.values.tolist()
    mycursor.executemany(sql, value)
    print(f"{stock_code} Record inserted")

    conn.commit()
    print(f'{stock_code} uploads to MySql  successfully, total {len(df)} records are inserted \n')
# Out:
# Database AStockMarket is connected!
# downloading 000001.SZ data from 20080101 to 2020121 from Tusahre
# 000001.SZ Record inserted
# 000001.SZ uploads to MySql  successfully, total 2851 records are inserted
#
# downloading 000002.SZ data from 20080101 to 2020121 from Tusahre
# 000002.SZ Record inserted
# 000002.SZ uploads to MySql  successfully, total 2776 records are inserted

# %%
import datetime

fromdate=datetime.datetime(2019, 7, 7)
todate=datetime.datetime(2021,1,1)
ticker = '000001.SZ'
print(str(ticker))

conn = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@')
if conn.is_connected():
    mycursor = conn.cursor(buffered=True)
    mycursor.execute('USE AStockMarket')
    print('Database AStockMarket is connected!')

    mycursor.execute(f"SELECT trade_date,open,high,low,close,vol FROM Daily WHERE ts_code = '{ticker}' AND trade_date between {datetime.datetime.strftime(fromdate,'%Y%m%d')} and {datetime.datetime.strftime(todate,'%Y%m%d')} ORDER BY trade_date ASC")

    results = mycursor.fetchall()

for i in results:
    print(i)
    #for i in results:
        #print(i)
    # get stock code from database
    # mycursor.execute('select ts_code from StockList')
    # query_result = mycursor.fetchall()
    # for i in range(len(query_result)):
    #     stock_code = [iterm for iterm in query_result[i]][0]
    #     print(stock_code)
    
    # for i in range(len(query_result)):
    #     output1 = [iterm for iterm in query_result[i]]
    #     print(output1)
    
    # output1 = ""
    # for row in query_result:
    #     output1 += '\'' + str(row[0]) + '\'' + ','
    #     #output2 += ' ' + str(row[0][0]) + ' ' + ','

        # To delete last char: ','
        #output1 = output1[:-1]
        #output2 = output2[:-1]

        #print(rows)          # (('1',), ('2',), ('3',), ('4',), ('5',))
        #print(output1)       # '1','2','3','4','5'
        #print(output2)       #  1 , 2 , 3 , 4 , 5 
    # sql = "INSERT INTO Daily VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"

    # for stock_code in stock_list:
    #     pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')
    #     df = pro.daily(ts_code=stock_code, start_date='20080101', end_date=today)
    #     print(f'downloaded {stock_code} data from 20080101 to {today} from Tusahre')

    #     value = df.values.tolist()
    #     mycursor.executemany(sql, value)
    #     print(f'{stock_code} Record inserted')

    #     conn.commit()
    #     print(f'{stock_code} uploads to MySql  successfully, total {len(df)} records are inserted \n')
# Out:
# 720.0), ('20201202', 19.93, 20.06, 19.52, 19.63, 889385.0), ('20201203', 19.78, 19.86, 19.17, 19.54, 714452.0), ('20201204', 19.47, 19.47, 18.97, 19.3, 891348.0), ('20201207', 19.31, 19.39, 18.68, 18.91, 873807.0), ('20201208', 18.92, 19.03, 18.53, 18.71, 719648.0), ('20201209', 18.79, 19.05, 18.68, 18.71, 677221.0), ('20201210', 18.73, 18.88, 18.45, 18.65, 607867.0), ('20201211', 18.71, 18.8, 18.22, 18.52, 887794.0), ('20201214', 18.6, 19.06, 18.5, 18.88, 835992.0), ('20201215', 18.8, 18.85, 18.15, 18.74, 788858.0), ('20201216', 18.8, 19.1, 18.58, 19.01, 689070.0), ('20201217', 18.91, 19.07, 18.6, 18.95, 686141.0), ('20201218', 19.0, 19.1, 18.23, 18.36, 1058760.0), ('20201221', 18.3, 18.64, 18.03, 18.28, 906878.0), ('20201222', 18.36, 18.65, 17.88, 17.9, 1028740.0), ('20201223', 17.96, 18.07, 17.79, 18.0, 750083.0), ('20201224', 18.15, 18.49, 18.05, 18.26, 632950.0), ('20201225', 18.26, 18.26, 17.8, 18.04, 577077.0), ('20201228', 18.02, 18.86, 17.96, 18.85, 1270340.0), ('20201229', 
# ...

# %%
import mysql.connector as mysql
from mysql.connector.errors import Error
import tushare as ts
import datetime


# Insert stock list into StockList Table 
#* load data from stocklist csv
today = datetime.datetime.now().strftime('%Y%m%d')
pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')
sql = "INSERT INTO Daily VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"



conn = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@', database = 'AStockMarket')
if conn.is_connected():
    print('Database AStockMarket is connected!')
    mycursor = conn.cursor(buffered=True)
    # get stock code from database
    
    #check the date when database is updated
    mycursor.execute(f'SELECT trade_date FROM Daily ORDER BY trade_date DESC LIMIT 1')
    results = mycursor.fetchone()
    print(results[0])

    fromdate = datetime.datetime.strptime(results[0],'%Y%m%d') + datetime.timedelta(days=1)
    fromdate = datetime.datetime.strftime(fromdate,'%Y%m%d')
    print(fromdate)
# Out:
# Database AStockMarket is connected!
# 20210128
# 20210129

# %%
import mysql.connector as mysql
from mysql.connector.errors import Error
import tushare as ts
import datetime


# Insert stock list into StockList Table 
#* load data from stocklist csv
today = datetime.datetime.now().strftime('%Y%m%d')
pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')
sql = "INSERT INTO Daily VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"



# connecting to MySql
conn = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@', database = 'AStockMarket')
if conn.is_connected():
    print('Database AStockMarket is connected!')
    mycursor = conn.cursor(buffered=True)
    # get stock code from database
    
    #check the date when database is updated
    mycursor.execute(f'SELECT trade_date FROM Daily ORDER BY trade_date DESC LIMIT 1')
    query_result = mycursor.fetchone()
    last_updated_date = query_result[0]
    
    # Retrive today's daily data from Tusahre from last updating date
    fromdate = datetime.datetime.strptime(query_result[0],'%Y%m%d') + datetime.timedelta(days=1)
    fromdate = datetime.datetime.strftime(fromdate,'%Y%m%d')
    
    if fromdate == today:
        print(f'database up to date!')
    
    else:
        df = pro.daily(start_date = fromdate, end_date = today)
        print(f'Original daily data from {fromdate} to {today} downlaoded from Tushare!')
# Out:
# Database AStockMarket is connected!
# database up to date!

# %%
import mysql.connector as mysql
from mysql.connector.errors import Error
import tushare as ts
import datetime
import pandas as pd


# Insert stock list into StockList Table 
#* load data from stocklist csv
today = datetime.datetime.now().strftime('%Y%m%d')
pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')




# connecting to MySql
conn = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@', database = 'AStockMarket')
if conn.is_connected():
    print('Database AStockMarket is connected!')
    mycursor = conn.cursor(buffered=True)
    # get stock code from database
    sql_daily = 'SELECT DISTINCT(ts_code) FROM Daily'
    sql_list = 'SELECT ts_code FROM StockList'
    #check the date when database is updated
    df_daily = pd.read_sql(sql_daily, conn)
    df_list = pd.read_sql(sql_list, conn)
    df_list['test1'] = 1
    df_daily['test1'] = 1

    print(df_list)
    print(df_daily)
# Out:
# Database AStockMarket is connected!
#         ts_code  test1
# 0     000001.SZ      1
# 1     000002.SZ      1
# 2     000004.SZ      1
# 3     000005.SZ      1
# 4     000006.SZ      1
# ...         ...    ...
# 4155  688777.SH      1
# 4156  688788.SH      1
# 4157  688819.SH      1
# 4158  688981.SH      1
# 4159  689009.SH      1
#
# [4160 rows x 2 columns]
#         ts_code  test1
# 0     000001.SZ      1
# 1     000002.SZ      1
# 2     000004.SZ      1
# 3     000005.SZ      1
# 4     000006.SZ      1
# ...         ...    ...
# 4139  688777.SH      1
# 4140  688788.SH      1
# 4141  688819.SH      1
# 4142  688981.SH      1
# 4143  689009.SH      1
#
# [4144 rows x 2 columns]

# %%
# Check which stocks that have no records
results = pd.merge(df_list,df_daily, how = 'left', on = 'ts_code')
print(results)
print(len(results[results.isna().any(axis=1)]))
print(results[results.isna().any(axis=1)])
# Out:
#         ts_code  test1_x  test1_y
# 0     000001.SZ        1      1.0
# 1     000002.SZ        1      1.0
# 2     000004.SZ        1      1.0
# 3     000005.SZ        1      1.0
# 4     000006.SZ        1      1.0
# ...         ...      ...      ...
# 4155  688777.SH        1      1.0
# 4156  688788.SH        1      1.0
# 4157  688819.SH        1      1.0
# 4158  688981.SH        1      1.0
# 4159  689009.SH        1      1.0
#
# [4160 rows x 3 columns]
# 16
#         ts_code  test1_x  test1_y
# 205   000637.SZ        1      NaN
# 215   000661.SZ        1      NaN
# 449   000999.SZ        1      NaN
# 971   002527.SZ        1      NaN
# 1695  300251.SZ        1      NaN
# 2451  600119.SH        1      NaN
# 2456  600125.SH        1      NaN
# 2595  600289.SH        1      NaN
# 2852  600612.SH        1      NaN
# 2899  600667.SH        1      NaN
# 2904  600675.SH        1      NaN
# 2908  600681.SH        1      NaN
# 2911  600684.SH        1      NaN
# ...

# %%
# stocks that have no records in MySQL
stock_list = results[results.isna().any(axis=1)]['ts_code']

# %%
# download data from tushare and update to MySQL for stocks that do not have records
conn = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@', database = 'AStockMarket')
if conn.is_connected():
    print('Database AStockMarket is connected!')
    mycursor = conn.cursor(buffered=True)

    # get stock code from database
    sql = "INSERT INTO Daily VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    
    
    i = 0
    for stock_code in stock_list:
        try:
            pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')
            df = pro.daily(ts_code=stock_code, start_date='20080101', end_date=today)
            print(f'downloaded {stock_code} data from 20080101 to {today} from Tusahre')

            value = df.values.tolist()
            mycursor.executemany(sql, value)
            print(f'{stock_code} Record inserted')

            conn.commit()
            print(f'{stock_code} uploads to MySql  successfully, total {len(df)} records are inserted \n')
            
            i = i + 1
            print(f'No.{i} stock updated')
            
        except:
            time.sleep(2)
# Out:
# Database AStockMarket is connected!
# downloaded 000637.SZ data from 20080101 to 20210129 from Tusahre
# 000637.SZ Record inserted
# 000637.SZ uploads to MySql  successfully, total 3147 records are inserted
#
# No.1 stock updated
# downloaded 000661.SZ data from 20080101 to 20210129 from Tusahre
# 000661.SZ Record inserted
# 000661.SZ uploads to MySql  successfully, total 3126 records are inserted
#
# No.2 stock updated
# downloaded 000999.SZ data from 20080101 to 20210129 from Tusahre
# 000999.SZ Record inserted
# 000999.SZ uploads to MySql  successfully, total 3004 records are inserted
#
# No.3 stock updated
# downloaded 002527.SZ data from 20080101 to 20210129 from Tusahre
# 002527.SZ Record inserted
# 002527.SZ uploads to MySql  successfully, total 2303 records are inserted
#
# No.4 stock updated
# downloaded 300251.SZ data from 20080101 to 20210129 from Tusahre
# 300251.SZ Record inserted
# 300251.SZ uploads to MySql  successfully, total 2193 records are inserted
#
# ...

# %%
import mysql.connector as mysql
from mysql.connector.errors import Error
import tushare as ts
import datetime
import pandas as pd


# Insert stock list into StockList Table 
#* load data from stocklist csv
today = datetime.datetime.now().strftime('%Y%m%d')
pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')

# connecting to MySql
conn = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@', database = 'AStockMarket')
if conn.is_connected():
    print('Database AStockMarket is connected!')
    mycursor = conn.cursor(buffered=True)
    # get stock code from database that have records at 20210129
    sql = "SELECT DISTINCT(ts_code) FROM Daily WHERE trade_date = 20210129 "
    #check the date when database is updated
    df = pd.read_sql(sql, conn)
    df['test3'] = 3

print(len(df))

# check which stocks that do not have records at 20210129
results2 = pd.merge(df_list, df, how = 'left', on = 'ts_code')
print(len(results2[results2.isna().any(axis=1)]))
print(results2[results2.isna().any(axis=1)])
# Out:
# Database AStockMarket is connected!
# 3407
# 753
#         ts_code  test1  test3
# 0     000001.SZ      1    NaN
# 1     000002.SZ      1    NaN
# 2     000004.SZ      1    NaN
# 3     000005.SZ      1    NaN
# 4     000006.SZ      1    NaN
# ...         ...    ...    ...
# 2724  600461.SH      1    NaN
# 2869  600634.SH      1    NaN
# 2947  600723.SH      1    NaN
# 3069  600859.SH      1    NaN
# 3711  603693.SH      1    NaN
#
# [753 rows x 3 columns]

# %%
# stocks that do not have records at 20210129
stock_list = results2[results2.isna().any(axis=1)]['ts_code']
print(stock_list)
# Out:
# 0       000001.SZ
# 1       000002.SZ
# 2       000004.SZ
# 3       000005.SZ
# 4       000006.SZ
#           ...
# 2724    600461.SH
# 2869    600634.SH
# 2947    600723.SH
# 3069    600859.SH
# 3711    603693.SH
# Name: ts_code, Length: 753, dtype: object

# %%
# download data from rtushare and updated to MySQL
conn = mysql.connect(host = 'localhost', user = 'root', passwd = '201202@', database = 'AStockMarket')
if conn.is_connected():
    print('Database AStockMarket is connected!')
    mycursor = conn.cursor(buffered=True)

    # get stock code from database
    sql = "INSERT INTO Daily VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    
    
    i = 0
    for stock_code in stock_list:
        try:
            pro = ts.pro_api('a0f192a7b75e15dd2d8c16f0a300a6e2b055f55d1589cfef6eb2fa01')
            df = pro.daily(ts_code=stock_code, start_date=today, end_date=today)
            print(f'downloaded {stock_code} data from 20080101 to {today} from Tusahre')

            value = df.values.tolist()
            mycursor.executemany(sql, value)
            print(f'{stock_code} Record inserted')

            conn.commit()
            print(f'{stock_code} uploads to MySql  successfully, total {len(df)} records are inserted')
            
            i = i + 1
            print(f'No.{i} stock updated \n')
            
        except:
            pass
# Out:
# 645 stock updated
#
# downloaded 002196.SZ data from 20080101 to 20210129 from Tusahre
# 002196.SZ Record inserted
# 002196.SZ uploads to MySql  successfully, total 1 records are inserted
# No.646 stock updated
#
# downloaded 002197.SZ data from 20080101 to 20210129 from Tusahre
# 002197.SZ Record inserted
# 002197.SZ uploads to MySql  successfully, total 1 records are inserted
# No.647 stock updated
#
# downloaded 002198.SZ data from 20080101 to 20210129 from Tusahre
# 002198.SZ Record inserted
# 002198.SZ uploads to MySql  successfully, total 1 records are inserted
# No.648 stock updated
#
# downloaded 002199.SZ data from 20080101 to 20210129 from Tusahre
# 002199.SZ Record inserted
# 002199.SZ uploads to MySql  successfully, total 1 records are inserted
# No.649 stock updated
#
# downloaded 002200.SZ data from 20080101 to 20210129 from Tusahre
# 002200.SZ Record inserted
# 002200.SZ uploads to MySql  successfully, total 1 records are inserted
# No.650 stock updated
#
# ...
